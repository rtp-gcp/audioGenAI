# %%
# Import the os package
import os

# Imports via openai docs
from pathlib import Path

# import the dotenv package
from dotenv import load_dotenv

import pprint

# From the IPython.display package, import display and Markdown
from IPython.display import display, Markdown, Audio

# %%
# Get the current working directory
cwd = os.getcwd()
# Construct the .env file path
env_path = os.path.join(cwd, '.env')

# Load the .env file
load_dotenv(dotenv_path=env_path)
# Out:
# True

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./jams-devpost-260ef9be751f.json"

# %%
# %%bash
# echo ${GOOGLE_APPLICATION_CREDENTIALS}
# gcloud config set project jams-devpost
# Out:
# ./jams-devpost-260ef9be751f.json
# Updated property [core/project].

# %% [markdown]
# from google AI Studio

# %%
from google.cloud import texttospeech

# %%
input_text = texttospeech.SynthesisInput(text="Hello, How are you?")

# %%
#client = texttospeech.TextToSpeechClient(credentials=os.environ["GOOGLE_APPLICATION_CREDENTIALS"])
client = texttospeech.TextToSpeechClient()

# %%
# Note: the voice can also be specified by name.
# Names of voices can be retrieved with client.list_voices().
voice = texttospeech.VoiceSelectionParams(
    language_code="en-US",
    name="en-US-Studio-O",
)

# %%
audio_config = texttospeech.AudioConfig(
    audio_encoding = texttospeech.AudioEncoding.LINEAR16,
    speaking_rate = 1
)

# %%
response = client.synthesize_speech(
    request={"input": input_text, "voice":voice, "audio_config": audio_config}
)

# %%
# The response's audio_content is binary.
with open("output.mp3", "wb") as out:
    out.write(response.audio_content)
    print('Audio content written to file "output.mp3"')
# Out:
# Audio content written to file "output.mp3"

# %%
Audio("output.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
